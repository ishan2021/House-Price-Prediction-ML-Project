# %% [markdown]
# # House Price Prediction
#
# # Model Evaluation and Saving
#
# In this notebook, we will:
#
# - Retrain the final selected model
# - Evaluate the model performance
# - Visualize predictions
# - Save the trained model
# - Verify that the saved model works correctly
#
# This notebook prepares the model for deployment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import joblib

# %%
df = pd.read_csv("../dataset/cleaned_house_price_dataset.csv")

# %% [markdown]
# ## Build the Final Model
#
# We will use the Gradient Boosting Regressor because it achieved the best overall performance among the tested models.

# %%
gb_model = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.05,
    random_state=42
)

gb_pipe = Pipeline([
    ("preprocessor", preprocessor),
    ("model", gb_model)
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       4     random_state=42
#       5 )
#       6
#       7 gb_pipe = Pipeline([
# ----> 8     ("preprocessor", preprocessor),
#       9     ("model", gb_model)
#      10 ])
#
# NameError: name 'preprocessor' is not defined
